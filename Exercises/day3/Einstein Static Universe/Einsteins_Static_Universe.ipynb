# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate as interp

# %% [markdown]
# In this notebook, you will try solving the acceleration equation for a Universe that is static.

# %% [markdown]
# In class, we derived the acceleraton equation
# \begin{equation}
# \frac{\ddot{a}}{a} = - \frac{4 \pi G}{3 c^2}\sum_w (1 + 3 w) \mathcal{E}_w + \frac{\Lambda}{3}
# \end{equation}
# **Problem 1**
# Show that this can be rewritten as
# \begin{equation}
# \frac{\ddot{a}}{a}H_0^2 = - \frac{1}{2} \left[ \sum_w (1 + 3 w)\Omega_{w,0} a^{-3(1+w)} - 2 \Omega_\Lambda \right]
# \end{equation}
# where $\Omega_{w,0}$ is the energy density over the critical density that we observe today and $\Omega_\Lambda$ is the ratio of the dark energy density over the critical energy density observed today.

# %% [markdown]
# Create a differential equation solver for This Universe using either the Euler or Runge Kutta methods that solves for $a(tH_0)$ where $H_0 a(0)=1$ and $\dot{a}(0)=1$. Use time units of $H_0^{-1}$. For clarity in plotting, make sure to set the output from your solver equal to zero when $a<0$.

# %%
## Solution

# %% [markdown]
# Test your solver on a flat, matter dominated Universe, plotting $a(t)$ versus $t/t_0$ and check that your solution agrees with the analytic solution that you derived in your previous homework.

# %%
## Solution

# %% [markdown]
# Plot $a(t)$ for a radiation Universe with $w=1/3$ and $\Omega_{1/3,0} = 0.1, 1., 10.$ and $\Omega_\Lambda = 0$.

# %%
## Solution

# %% [markdown]
# Do the same when we have a Universe with matter and no Cosmological constant; $\Omega_{0,0} = 0.1, 1., 10$.
#
# Compare your solutions to the radiation dominated Universe by putting them both on the same plot.

# %%
## Solution

# %% [markdown]
# Now lets construct an Einstein Static Universe by choosing $\Omega_\Lambda$ such that $\ddot{a} = 0$ for a
# * matter dominated Universe
# * radiation dominated Universe.
# Using some algebra, what values of $\Omega_\Lambda$ do we need to construct a static Universe if $\Omega_{0,0} = 0.3$ or $\Omega_{1/3,0} = 0.3$?
# Verify that your Universe's are static by plotting $a(t)$ for each of them as a function of time. Make sure to set $\dot{a}=0!$

# %%
## Solution

# %% [markdown]
# What happens to the above Universe's if you change $a$ by a very small amount, e.g. let $a(t=0) = 1+10^{-6}$. Do the Universe's remain static? Plot your answers :)

# %%
## Solution
